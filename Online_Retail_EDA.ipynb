# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  
df = pd.read_excel("Online Retail.xlsx")
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
import zipfile

with zipfile.ZipFile("online+retail.zip", "r") as zip_ref:
    zip_ref.extractall("online_retail_data")

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# c:\Users\Sabith\Downloads\letsupgrade.project
# ['online+retail.zip', 'Online_Retail_EDA.ipynb']

# %%
import os

print(os.listdir("online_retail_data"))
# Out:
# ['Online Retail.xlsx']

# %%
df = pd.read_excel("online_retail_data/Online Retail.xlsx")

# %%
# %pip install openpyxl
# Out:
# ...
#
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
#    -------------------- ------------------- 1/2 [openpyxl]
# ...

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.shape
# Out:
# (541909, 8)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country'],
#       dtype='str')

# %%
for columns in df.columns:
    print(columns)
# Out:
# InvoiceNo
# StockCode
# Description
# Quantity
# InvoiceDate
# UnitPrice
# CustomerID
# Country

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[us]
# UnitPrice             float64
# CustomerID            float64
# Country                   str
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
df.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df.describe()
#
# NameError: name 'df' is not defined

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("Online Retail.xlsx")

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  UnitPrice  CustomerID         Country
# 0 2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2 2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3 2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4 2010-12-01 08:26:00       3.39     17850.0  United Kingdom

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description      1454
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     135080
# Country             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(5268)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel("Online Retail.xlsx")
df.shape
# Out:
# (541909, 8)

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (536641, 8)

# %%
df = df.dropna(subset=['Description'])

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133583
# Country             0
# dtype: int64

# %%
df=df.dropna(subset=["Description"])

# %%
df.isnull().sum()
# Out:
# InvoiceNo           0
# StockCode           0
# Description         0
# Quantity            0
# InvoiceDate         0
# UnitPrice           0
# CustomerID     133583
# Country             0
# dtype: int64

# %%
(df['Quantity']<0).sum()
# Out:
# np.int64(9725)

# %%
(df['UnitPrice']<0).sum()
# Out:
# np.int64(2)

# %%
df = df[df['Quantity'] > 0]

# %%
df = df[df['UnitPrice'] > 0]

# %%
df.shape
# Out:
# (524878, 8)

# %%
print("Negative Quantity:", (df['Quantity'] < 0).sum())
print("Invalid UnitPrice:", (df['UnitPrice'] <= 0).sum())
# Out:
# Negative Quantity: 0
# Invalid UnitPrice: 0

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[us]
# UnitPrice             float64
# CustomerID            float64
# Country                   str
# dtype: object

# %%
df.drop_duplicates()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
df.shape
# Out:
# (524878, 8)

# %%
df = df.dropna(subset=["CustomerID"])

# %%
df.shape
# Out:
# (392692, 8)

# %%
df['sales']=df['Quantity'] * df['UnitPrice']

# %%
df[['Quantity','UnitPrice','sales']].head()
# Out:
#    Quantity  UnitPrice  sales
# 0         6       2.55  15.30
# 1         6       3.39  20.34
# 2         8       2.75  22.00
# 3         6       3.39  20.34
# 4         6       3.39  20.34

# %%
total_sales=df['sales'].sum()
print(f"Total Sales: {total_sales}")
# Out:
# Total Sales: 8887208.894000001

# %%
total_orders = df["InvoiceNo"].nunique()

print("Total Orders:", total_orders)
# Out:
# Total Orders: 18532

# %%
df["InvoiceNo"].nunique()
# Out:
# 18532

# %%
print(list(df.columns))
# Out:
# ['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate', 'UnitPrice', 'CustomerID', 'Country', 'sales']

# %%
Total_Customers = df["CustomerID"].nunique()
print(f"Total customers:{Total_Customers}")
# Out:
# Total customers:4338

# %%
country_sales = df.groupby("Country")["sales"].sum().sort_values(ascending=False)

country_sales.head(10)
# Out:
# Country
# United Kingdom    7285024.644
# Netherlands        285446.340
# EIRE               265262.460
# Germany            228678.400
# France             208934.310
# Australia          138453.810
# Spain               61558.560
# Switzerland         56443.950
# Belgium             41196.340
# Sweden              38367.830
# Name: sales, dtype: float64

# %%
product_sales = df.groupby("Description")["sales"].sum().sort_values(ascending=False)

product_sales.head(10)
# Out:
# Description
# PAPER CRAFT , LITTLE BIRDIE           168469.60
# REGENCY CAKESTAND 3 TIER              142264.75
# WHITE HANGING HEART T-LIGHT HOLDER    100392.10
# JUMBO BAG RED RETROSPOT                85040.54
# MEDIUM CERAMIC TOP STORAGE JAR         81416.73
# POSTAGE                                77803.96
# PARTY BUNTING                          68785.23
# ASSORTED COLOUR BIRD ORNAMENT          56413.03
# Manual                                 53419.93
# RABBIT NIGHT LIGHT                     51251.24
# Name: sales, dtype: float64

# %%
df["Month"] = df["InvoiceDate"].dt.to_period("M")

monthly_sales = df.groupby("Month")["sales"].sum()

monthly_sales
# Out:
# Month
# 2010-12     570422.730
# 2011-01     568101.310
# 2011-02     446084.920
# 2011-03     594081.760
# 2011-04     468374.331
# 2011-05     677355.150
# 2011-06     660046.050
# 2011-07     598962.901
# 2011-08     644051.040
# 2011-09     950690.202
# 2011-10    1035642.450
# 2011-11    1156205.610
# 2011-12     517190.440
# Freq: M, Name: sales, dtype: float64

# %%
customer_sales = df.groupby("CustomerID")["sales"].sum().sort_values(ascending=False)

customer_sales.head(10)
# Out:
# CustomerID
# 14646.0    280206.02
# 18102.0    259657.30
# 17450.0    194390.79
# 16446.0    168472.50
# 14911.0    143711.17
# 12415.0    124914.53
# 14156.0    117210.08
# 17511.0     91062.38
# 16029.0     80850.84
# 12346.0     77183.60
# Name: sales, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 5))

monthly_sales.plot(kind="line", marker="o")

plt.title("Monthly Sales Trend")
plt.xlabel("Month")
plt.ylabel("Total Sales")
plt.xticks(rotation=45)
plt.grid(True)

plt.show()

# %%
top_products = product_sales.head(10).sort_values()

plt.figure(figsize=(10, 6))

top_products.plot(kind="barh")

plt.title("Top 10 Products by Sales")
plt.xlabel("Total Sales")
plt.ylabel("Product")

plt.show()

# %%
total_products = df["Description"].nunique()

print("Total Products:", total_products)
# Out:
# Total Products: 3877

# %%
best_product = product_sales.idxmax()
best_product_sales = product_sales.max()

print("Best Selling Product:", best_product)
print("Best Product Sales:", best_product_sales)
# Out:
# Best Selling Product: PAPER CRAFT , LITTLE BIRDIE
# Best Product Sales: 168469.6

# %%
top_customer = customer_sales.idxmax()
top_customer_sales = customer_sales.max()

print("Top Customer ID:", top_customer)
print("Top Customer Sales:", top_customer_sales)
# Out:
# Top Customer ID: 14646.0
# Top Customer Sales: 280206.02

# %%
plt.figure(figsize=(10,6))

country_sales.head(10).sort_values().plot(kind="barh")

plt.title("Top 10 Countries by Sales")
plt.xlabel("Total Sales")
plt.ylabel("Country")

plt.tight_layout()
plt.show()

# %%
top_customers = customer_sales.head(10).sort_values()

plt.figure(figsize=(10,6))

top_customers.plot(kind="barh")

plt.title("Top 10 Customers by Sales")
plt.xlabel("Total Sales")
plt.ylabel("Customer ID")

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,6))

plt.boxplot(df["sales"])

plt.title("Sales Distribution and Outliers")
plt.ylabel("Sales")

plt.show()

# %%
Q1 = df["sales"].quantile(0.25)
Q3 = df["sales"].quantile(0.75)

IQR = Q3 - Q1

lower_limit = Q1 - 1.5 * IQR
upper_limit = Q3 + 1.5 * IQR

outliers = df[
    (df["sales"] < lower_limit) |
    (df["sales"] > upper_limit)
]

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower Limit:", lower_limit)
print("Upper Limit:", upper_limit)
print("Number of Outliers:", len(outliers))
# Out:
# Q1: 4.949999999999999
# Q3: 19.799999999999997
# IQR: 14.849999999999998
# Lower Limit: -17.325
# Upper Limit: 42.074999999999996
# Number of Outliers: 31231

# %%
outliers.sort_values("sales", ascending=False)[
    ["InvoiceNo", "Description", "Quantity", "UnitPrice", "CustomerID", "Country", "sales"]
].head(10)
# Out:
#        InvoiceNo                          Description  Quantity  UnitPrice  \
# 540421    581483          PAPER CRAFT , LITTLE BIRDIE     80995       2.08
# 61619     541431       MEDIUM CERAMIC TOP STORAGE JAR     74215       1.04
# 222680    556444       PICNIC BASKET WICKER 60 PIECES        60     649.50
# 173382    551697                              POSTAGE         1    8142.75
# 348325    567423  SET OF TEA COFFEE SUGAR TINS PANTRY      1412       5.06
# 160546    550461   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114       2.10
# 52711     540815   FAIRY CAKE FLANNEL ASSORTED COLOUR      3114       2.10
# 421601    573003                   RABBIT NIGHT LIGHT      2400       2.08
# 52709     540815   WHITE HANGING HEART T-LIGHT HOLDER      1930       2.55
# 160542    550461   WHITE HANGING HEART T-LIGHT HOLDER      1930       2.40
#
#         CustomerID         Country      sales
# 540421     16446.0  United Kingdom  168469.60
# 61619      12346.0  United Kingdom   77183.60
# ...

# %%
df["UnitPrice"].describe()
# Out:
# count    392692.000000
# mean          3.125914
# std          22.241836
# min           0.001000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        8142.750000
# Name: UnitPrice, dtype: float64

# %%
df.sort_values("UnitPrice", ascending=False)[
    ["InvoiceNo", "Description", "Quantity", "UnitPrice", "CustomerID", "Country", "sales"]
].head(10)
# Out:
#        InvoiceNo Description  Quantity  UnitPrice  CustomerID         Country  \
# 173382    551697     POSTAGE         1    8142.75     16029.0  United Kingdom
# 422351    573077      Manual         1    4161.06     12536.0          France
# 422376    573080      Manual         1    4161.06     12536.0          France
# 406406    571751      Manual         1    3949.32     12744.0       Singapore
# 374542    569382      Manual         1    3155.95     15502.0  United Kingdom
# 297438    562946      Manual         1    2500.00     15581.0  United Kingdom
# 144826    548813      Manual         1    2382.92     12744.0       Singapore
# 406407    571751      Manual         1    2118.74     12744.0       Singapore
# 144829    548820      Manual         1    2053.07     12744.0       Singapore
# 343000    566927      Manual         1    2033.10     17846.0  United Kingdom
#
#           sales
# 173382  8142.75
# 422351  4161.06
# 422376  4161.06
# 406406  3949.32
# 374542  3155.95
# ...

# %%
print(df["Description"].value_counts().head(20))
# Out:
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2016
# REGENCY CAKESTAND 3 TIER              1713
# JUMBO BAG RED RETROSPOT               1615
# ASSORTED COLOUR BIRD ORNAMENT         1395
# PARTY BUNTING                         1389
# LUNCH BAG RED RETROSPOT               1303
# SET OF 3 CAKE TINS PANTRY DESIGN      1152
# POSTAGE                               1099
# LUNCH BAG  BLACK SKULL.               1078
# PACK OF 72 RETROSPOT CAKE CASES       1050
# SPOTTY BUNTING                        1014
# PAPER CHAIN KIT 50'S CHRISTMAS        1003
# LUNCH BAG SPACEBOY DESIGN              993
# HEART OF WICKER SMALL                  979
# LUNCH BAG CARS BLUE                    977
# NATURAL SLATE HEART CHALKBOARD         972
# LUNCH BAG PINK POLKADOT                941
# LUNCH BAG SUKI DESIGN                  915
# REX CASH+CARRY JUMBO SHOPPER           897
# ALARM CLOCK BAKELIKE RED               886
# Name: count, dtype: int64

# %%
print("POSTAGE records:", (df["Description"] == "POSTAGE").sum())
print("Manual records:", (df["Description"] == "Manual").sum())
# Out:
# POSTAGE records: 1099
# Manual records: 279

# %%
df_clean = df[
    ~df["Description"].isin(["POSTAGE", "Manual"])
].copy()

print("Original records:", len(df))
print("Clean records:", len(df_clean))
print("Removed records:", len(df) - len(df_clean))
# Out:
# Original records: 392692
# Clean records: 391314
# Removed records: 1378

# %%
df_clean = df[
    ~df["Description"].isin(["POSTAGE", "Manual"])
].copy()

# %%
print("Clean Dataset Shape:", df_clean.shape)

print("\nMissing Values:")
print(df_clean.isnull().sum())

print("\nDuplicate Records:")
print(df_clean.duplicated().sum())

print("\nNegative Quantity:")
print((df_clean["Quantity"] < 0).sum())

print("\nNegative Sales:")
print((df_clean["sales"] < 0).sum())
# Out:
# Clean Dataset Shape: (391314, 10)
#
# Missing Values:
# InvoiceNo      0
# StockCode      0
# Description    0
# Quantity       0
# InvoiceDate    0
# UnitPrice      0
# CustomerID     0
# Country        0
# sales          0
# Month          0
# dtype: int64
#
# Duplicate Records:
# 0
#
# Negative Quantity:
# 0
#
# Negative Sales:
# 0

# %%
print("Sales Statistics:")
print(df_clean["sales"].describe())

print("\nQuantity Statistics:")
print(df_clean["Quantity"].describe())

print("\nUnit Price Statistics:")
print(df_clean["UnitPrice"].describe())
# Out:
# Sales Statistics:
# count    391314.000000
# mean         22.375854
# std         310.920054
# min           0.001000
# 25%           4.950000
# 50%          11.900000
# 75%          19.800000
# max      168469.600000
# Name: sales, dtype: float64
#
# Quantity Statistics:
# count    391314.000000
# mean         13.140212
# std         180.770109
# min           1.000000
# 25%           2.000000
# 50%           6.000000
# 75%          12.000000
# max       80995.000000
# Name: Quantity, dtype: float64
#
# Unit Price Statistics:
# count    391314.000000
# mean          2.921056
# std           7.267967
# min           0.001000
# 25%           1.250000
# 50%           1.950000
# 75%           3.750000
# max        1599.260000
# Name: UnitPrice, dtype: float64

# %%
# ==============================
# BUSINESS KPIs
# ==============================

total_sales = df_clean["sales"].sum()
total_orders = df_clean["InvoiceNo"].nunique()
total_customers = df_clean["CustomerID"].nunique()
total_products = df_clean["Description"].nunique()

average_order_value = total_sales / total_orders

print("Total Sales:", round(total_sales, 2))
print("Total Orders:", total_orders)
print("Total Customers:", total_customers)
print("Total Products:", total_products)
print("Average Order Value:", round(average_order_value, 2))
# Out:
# Total Sales: 8755985.0
# Total Orders: 18416
# Total Customers: 4335
# Total Products: 3875
# Average Order Value: 475.46

# %%
# ==============================
# CUSTOMER SEGMENTATION
# ==============================

customer_sales = df_clean.groupby("CustomerID")["sales"].sum()

customer_segment = pd.cut(
    customer_sales,
    bins=[0, 500, 2000, 5000, float("inf")],
    labels=["Low Value", "Medium Value", "High Value", "VIP"]
)

print(customer_segment.value_counts().sort_index())
# Out:
# sales
# Low Value       1781
# Medium Value    1671
# High Value       615
# VIP              268
# Name: count, dtype: int64

# %%
# ==============================
# CUSTOMER SEGMENTATION CHART
# ==============================

segment_counts = customer_segment.value_counts().sort_index()

plt.figure(figsize=(8, 5))

segment_counts.plot(kind="bar")

plt.title("Customer Segmentation")
plt.xlabel("Customer Segment")
plt.ylabel("Number of Customers")
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
# ==============================
# SALES BY CUSTOMER SEGMENT
# ==============================

customer_segment_df = pd.DataFrame({
    "CustomerID": customer_sales.index,
    "TotalSales": customer_sales.values,
    "Segment": customer_segment.values
})

segment_sales = customer_segment_df.groupby("Segment")["TotalSales"].sum()

print("Sales by Customer Segment:")
print(segment_sales)
# Out:
# Sales by Customer Segment:
# Segment
# Low Value        460492.511
# Medium Value    1727580.972
# High Value      1871608.541
# VIP             4696302.980
# Name: TotalSales, dtype: float64

# %%
plt.figure(figsize=(8, 5))

segment_sales.plot(kind="bar")

plt.title("Sales by Customer Segment")
plt.xlabel("Customer Segment")
plt.ylabel("Total Sales")
plt.xticks(rotation=0)

plt.tight_layout()
plt.show()

# %%
# ==============================
# MONTHLY SALES GROWTH
# ==============================

monthly_sales = df_clean.groupby("Month")["sales"].sum()

monthly_growth = monthly_sales.pct_change() * 100

print("Monthly Sales:")
print(monthly_sales)

print("\nMonthly Sales Growth (%):")
print(monthly_growth.round(2))
# Out:
# Monthly Sales:
# Month
# 2010-12     565764.560
# 2011-01     562897.910
# 2011-02     442493.590
# 2011-03     583843.850
# 2011-04     454855.881
# 2011-05     659693.490
# 2011-06     653764.920
# 2011-07     592103.791
# 2011-08     635875.550
# 2011-09     941364.462
# 2011-10    1006465.320
# 2011-11    1142869.340
# 2011-12     513992.340
# Freq: M, Name: sales, dtype: float64
#
# Monthly Sales Growth (%):
# Month
# 2010-12      NaN
# 2011-01    -0.51
# 2011-02   -21.39
# 2011-03    31.94
# 2011-04   -22.09
# 2011-05    45.03
# 2011-06    -0.90
# 2011-07    -9.43
# 2011-08     7.39
# 2011-09    48.04
# 2011-10     6.92
# 2011-11    13.55
# 2011-12   -55.03
# Freq: M, Name: sales, dtype: float64

# %%
# ==============================
# MONTHLY SALES GROWTH CHART
# ==============================

plt.figure(figsize=(12, 5))

monthly_growth.dropna().plot(kind="bar")

plt.title("Monthly Sales Growth (%)")
plt.xlabel("Month")
plt.ylabel("Sales Growth (%)")
plt.xticks(rotation=45)

plt.axhline(0, linewidth=1)

plt.tight_layout()
plt.show()
